# %% [markdown]
# # Exoplanet Detection

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import imblearn
import keras

# %%
train_df = pd.read_csv('D:/UMANG/DataSets/kepler-labelled-time-series-data/exoTrain.csv').fillna(0)
test_df = pd.read_csv('D:/UMANG/DataSets/kepler-labelled-time-series-data/exoTest.csv').fillna(0)

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (5087, 3198)
# (570, 3198)

# %%
train_df['Label'] = train_df['LABEL'] - 1
test_df['Label'] = test_df['LABEL'] - 1
train_df = train_df.drop(columns='LABEL')
test_df = test_df.drop(columns='LABEL')

# %%
train_y = train_df['Label']
train_x = train_df.drop(columns='Label')
test_y = test_df['Label']
test_x = test_df.drop(columns='Label')

# %% [markdown]
# ## Data Exploration

# %%
count_labels = train_y.groupby(by=train_y).count()
count_labels = count_labels.to_frame(name='Count')
count_labels = count_labels.reset_index()
g2 = sns.barplot(x='Label', y='Count', data=count_labels,palette=sns.color_palette("Paired"))
g2.set(xticklabels=['No Exoplanet','Contains Exoplanet'])
plt.title('Count of Exoplanet Containing Stars')
plt.savefig('Count_stars.png',dpi=600)

# %%
plot_train_df = train_x.loc[:0,:'FLUX.1000'].reset_index()
plot_train_df = plot_train_df.melt(id_vars=['index'],var_name="Flux Index", 
        value_name="Flux Intensity")
sns.set_style("dark")
g = sns.lineplot(x="Flux Index", y="Flux Intensity", hue="index",
                  data=plot_train_df,legend=False)
g.set(xticklabels=[])
plt.title('Flux Intensity for a single Exoplanet Containing Stars')
plt.savefig('Flux_Intensity.png',dpi=800)

# %%
plot_train_df = train_x.loc[:10,:'FLUX.50'].reset_index()
plot_train_df = plot_train_df.melt(id_vars=['index'],var_name="Flux Index", 
        value_name="Flux Intensity")
sns.set_style("dark")
g = sns.lineplot(x="Flux Index", y="Flux Intensity", hue="index",
                  data=plot_train_df,legend=False)
g.set(xticklabels=[])
plt.title('Flux Intensity for a multiple Exoplanet Containing Stars')
plt.savefig('Flux_Intensity.png',dpi=800)

# %%
exo_train = train_x[train_y == 1].reset_index().melt(id_vars=['index'],var_name="Flux Index", 
        value_name="Flux Intensity")
non_exo_train = train_x[train_y == 0].reset_index().melt(id_vars=['index'],var_name="Flux Index", 
        value_name="Flux Intensity")
print(exo_train.groupby('index').std().mean())
print(non_exo_train.groupby('index').std().mean())
# Out:
# Flux Intensity    1113.599545
# dtype: float64
# Flux Intensity    1267.318598
# dtype: float64

# %% [markdown]
# ### Correlation Matrix

# %%
corr_matrix = train_x.loc[:37,:'FLUX.10'].corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_2903f_row0_col0, #T_2903f_row0_col1, #T_2903f_row0_col2, #T_2903f_row0_col3, #T_2903f_row0_col4, #T_2903f_row0_col5, #T_2903f_row0_col6, #T_2903f_row1_col0, #T_2903f_row1_col1, #T_2903f_row1_col2, #T_2903f_row1_col3, #T_2903f_row1_col4, #T_2903f_row1_col5, #T_2903f_row1_col6, #T_2903f_row2_col0, #T_2903f_row2_col1, #T_2903f_row2_col2, #T_2903f_row2_col3, #T_2903f_row2_col4, #T_2903f_row2_col5, #T_2903f_row2_col6, #T_2903f_row3_col0, #T_2903f_row3_col1, #T_2903f_row3_col2, #T_2903f_row3_col3, #T_2903f_row3_col4, #T_2903f_row3_col5, #T_2903f_row3_col6, #T_2903f_row4_col0, #T_2903f_row4_col1, #T_2903f_row4_col2, #T_2903f_row4_col3, #T_2903f_row4_col4, #T_2903f_row4_col5, #T_2903f_row4_col6, #T_2903f_row5_col0, #T_2903f_row5_col1, #T_2903f_row5_col2, #T_2903f_row5_col3, #T_2903f_row5_col4, #T_2903f_row5_col5, #T_2903f_row5_col6, #T_2903f_row5_col7, #T_2903f_row6_col0, #T_2903f_row6_col1, #T_2903f_row6_col2, #T_2903f_row6_col3, #T_2903f_row6_col4, #T_2903f_row6_col5, #T_2903f_row6_col6, #T_2903f_row6_col7, #T_2903f_row7_col5, #T_2903f_row7_col6, #T_2903f_row7_col7, #T_2903f_row8_col8, #T_2903f_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2903f_row0_col7, #T_2903f_row1_col7, #T_2903f_row2_col7, #T_2903f_row3_col7, #T_2903f_row4_col7, #T_2903f_row7_col0, #T_2903f_row7_col1, #T_2903f_row7_col2, #T_2903f_row7_col3, #T_2903f_row7_col4 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_2903f_row0_col8, #T_2903f_row1_col8 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_2903f_row0_col9, #T_2903f_row1_col9, #T_2903f_row2_col9, #T_2903f_row3_col9, #T_2903f_row9_col0, #T_2903f_row9_col1, #T_2903f_row9_col2, #T_2903f_row9_col3, #T_2903f_row9_col4, #T_2903f_row9_col5, #T_2903f_row9_col6, #T_2903f_row9_col7, #T_2903f_row9_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2903f_row2_col8 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_2903f_row3_col8 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_2903f_row4_col8 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_2903f_row4_col9 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_2903f_row5_col8 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_2903f_row5_col9, #T_2903f_row6_col9 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_2903f_row6_col8 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_2903f_row7_col8, #T_2903f_row8_col5 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_2903f_row7_col9 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_2903f_row8_col0, #T_2903f_row8_col1 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_2903f_row8_col2 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_2903f_row8_col3 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_2903f_row8_col4 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_2903f_row8_col6 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_2903f_row8_col7 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_2903f_row8_col9 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# </style>
# <table id="T_2903f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2903f_level0_col0" class="col_heading level0 col0" >FLUX.1</th>
#       <th id="T_2903f_level0_col1" class="col_heading level0 col1" >FLUX.2</th>
#       <th id="T_2903f_level0_col2" class="col_heading level0 col2" >FLUX.3</th>
#       <th id="T_2903f_level0_col3" class="col_heading level0 col3" >FLUX.4</th>
#       <th id="T_2903f_level0_col4" class="col_heading level0 col4" >FLUX.5</th>
#       <th id="T_2903f_level0_col5" class="col_heading level0 col5" >FLUX.6</th>
#       <th id="T_2903f_level0_col6" class="col_heading level0 col6" >FLUX.7</th>
#       <th id="T_2903f_level0_col7" class="col_heading level0 col7" >FLUX.8</th>
#       <th id="T_2903f_level0_col8" class="col_heading level0 col8" >FLUX.9</th>
#       <th id="T_2903f_level0_col9" class="col_heading level0 col9" >FLUX.10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2903f_level0_row0" class="row_heading level0 row0" >FLUX.1</th>
#       <td id="T_2903f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_2903f_row0_col1" class="data row0 col1" >0.999991</td>
#       <td id="T_2903f_row0_col2" class="data row0 col2" >0.999934</td>
#       <td id="T_2903f_row0_col3" class="data row0 col3" >0.999801</td>
#       <td id="T_2903f_row0_col4" class="data row0 col4" >0.999594</td>
#       <td id="T_2903f_row0_col5" class="data row0 col5" >0.998802</td>
#       <td id="T_2903f_row0_col6" class="data row0 col6" >0.998145</td>
#       <td id="T_2903f_row0_col7" class="data row0 col7" >0.986388</td>
#       <td id="T_2903f_row0_col8" class="data row0 col8" >0.661413</td>
#       <td id="T_2903f_row0_col9" class="data row0 col9" >-0.953298</td>
#     </tr>
#     <tr>
#       <th id="T_2903f_level0_row1" class="row_heading level0 row1" >FLUX.2</th>
#       <td id="T_2903f_row1_col0" class="data row1 col0" >0.999991</td>
#       <td id="T_2903f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_2903f_row1_col2" class="data row1 col2" >0.999970</td>
#       <td id="T_2903f_row1_col3" class="data row1 col3" >0.999866</td>
#       <td id="T_2903f_row1_col4" class="data row1 col4" >0.999689</td>
#       <td id="T_2903f_row1_col5" class="data row1 col5" >0.998970</td>
#       <td id="T_2903f_row1_col6" class="data row1 col6" >0.998343</td>
#       <td id="T_2903f_row1_col7" class="data row1 col7" >0.986949</td>
#       <td id="T_2903f_row1_col8" class="data row1 col8" >0.664021</td>
#       <td id="T_2903f_row1_col9" class="data row1 col9" >-0.952280</td>
#     </tr>
#     <tr>
#       <th id="T_2903f_level0_row2" class="row_heading level0 row2" >FLUX.3</th>
#       <td id="T_2903f_row2_col0" class="data row2 col0" >0.999934</td>
#       <td id="T_2903f_row2_col1" class="data row2 col1" >0.999970</td>
#       <td id="T_2903f_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_2903f_row2_col3" class="data row2 col3" >0.999961</td>
#       <td id="T_2903f_row2_col4" class="data row2 col4" >0.999847</td>
#       <td id="T_2903f_row2_col5" class="data row2 col5" >0.999282</td>
#       <td id="T_2903f_row2_col6" class="data row2 col6" >0.998741</td>
#       <td id="T_2903f_row2_col7" class="data row2 col7" >0.988129</td>
#       <td id="T_2903f_row2_col8" class="data row2 col8" >0.669639</td>
#       <td id="T_2903f_row2_col9" class="data row2 col9" >-0.949962</td>
#     </tr>
#     <tr>
#       <th id="T_2903f_level0_row3" class="row_heading level0 row3" >FLUX.4</th>
#       <td id="T_2903f_row3_col0" class="data row3 col0" >0.999801</td>
#       <td id="T_2903f_row3_col1" class="data row3 col1" >0.999866</td>
#       <td id="T_2903f_row3_col2" class="data row3 col2" >0.999961</td>
#       <td id="T_2903f_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_2903f_row3_col4" class="data row3 col4" >0.999959</td>
#       <td id="T_2903f_row3_col5" class="data row3 col5" >0.999571</td>
#       <td id="T_2903f_row3_col6" class="data row3 col6" >0.999137</td>
#       <td id="T_2903f_row3_col7" class="data row3 col7" >0.989427</td>
#       <td id="T_2903f_row3_col8" class="data row3 col8" >0.676058</td>
#       <td id="T_2903f_row3_col9" class="data row3 col9" >-0.947216</td>
#     </tr>
#     <tr>
#       <th id="T_2903f_level0_row4" class="row_heading level0 row4" >FLUX.5</th>
#       <td id="T_2903f_row4_col0" class="data row4 col0" >0.999594</td>
#       <td id="T_2903f_row4_col1" class="data row4 col1" >0.999689</td>
#       <td id="T_2903f_row4_col2" class="data row4 col2" >0.999847</td>
#       <td id="T_2903f_row4_col3" class="data row4 col3" >0.999959</td>
#       <td id="T_2903f_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_2903f_row4_col5" class="data row4 col5" >0.999788</td>
#       <td id="T_2903f_row4_col6" class="data row4 col6" >0.999458</td>
#       <td id="T_2903f_row4_col7" class="data row4 col7" >0.990639</td>
#       <td id="T_2903f_row4_col8" class="data row4 col8" >0.682391</td>
#       <td id="T_2903f_row4_col9" class="data row4 col9" >-0.944414</td>
#     </tr>

# %%
non_exo_df = train_x.loc[55:55,:'FLUX.3000'].reset_index()
non_exo_df = non_exo_df.melt(id_vars=['index'],var_name="Flux Index", 
        value_name="Flux Intensity")
g1 = sns.lineplot(x="Flux Index", y="Flux Intensity", hue="index",
                  data=non_exo_df ,legend=False)
g1.set(xticklabels=[])
plt.title('Flux Intensity for Non-Exoplanet Containing Star')
plt.savefig('Flux_Intensity_NonExo_single.png',dpi=800)

# %%
non_exo_df = train_x.loc[50:55,:'FLUX.800'].reset_index()
non_exo_df = non_exo_df.melt(id_vars=['index'],var_name="Flux Index", 
        value_name="Flux Intensity")
g1 = sns.lineplot(x="Flux Index", y="Flux Intensity", hue="index",
                  data=non_exo_df ,legend=False)
g1.set(xticklabels=[])
plt.title('Flux Intensity for many Non-Exoplanet Containing Star')
plt.savefig('Flux_Intensity_NonExo_single.png',dpi=800)

# %%
corr_matrix = train_x.loc[38:1000,:'FLUX.10'].corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b0a41_row0_col0, #T_b0a41_row1_col1, #T_b0a41_row2_col2, #T_b0a41_row3_col3, #T_b0a41_row4_col4, #T_b0a41_row5_col5, #T_b0a41_row6_col6, #T_b0a41_row7_col7, #T_b0a41_row8_col8, #T_b0a41_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b0a41_row0_col1 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_b0a41_row0_col2, #T_b0a41_row0_col3, #T_b0a41_row0_col4, #T_b0a41_row0_col7, #T_b0a41_row0_col8, #T_b0a41_row0_col9, #T_b0a41_row3_col5, #T_b0a41_row3_col6, #T_b0a41_row7_col1, #T_b0a41_row8_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b0a41_row0_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_b0a41_row0_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_b0a41_row1_col0 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_b0a41_row1_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_b0a41_row1_col3 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_b0a41_row1_col4 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_b0a41_row1_col5 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_b0a41_row1_col6, #T_b0a41_row7_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_b0a41_row1_col7 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_b0a41_row1_col8, #T_b0a41_row7_col9 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_b0a41_row1_col9 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_b0a41_row2_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_b0a41_row2_col1, #T_b0a41_row6_col4 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_b0a41_row2_col3, #T_b0a41_row7_col8 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_b0a41_row2_col4 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_b0a41_row2_col5, #T_b0a41_row3_col7 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b0a41_row2_col6, #T_b0a41_row6_col2 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_b0a41_row2_col7 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_b0a41_row2_col8 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_b0a41_row2_col9 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_b0a41_row3_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_b0a41_row3_col1 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_b0a41_row3_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_b0a41_row3_col4 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_b0a41_row3_col8 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_b0a41_row3_col9 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_b0a41_row4_col0, #T_b0a41_row7_col5 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_b0a41_row4_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_b0a41_row4_col2 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_b0a41_row4_col3 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_b0a41_row4_col5 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_b0a41_row4_col6, #T_b0a41_row5_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_b0a41_row4_col7 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_b0a41_row4_col8 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_b0a41_row4_col9 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_b0a41_row5_col0 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_b0a41_row5_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_b0a41_row5_col3 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_b0a41_row5_col4 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_b0a41_row5_col6 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_b0a41_row5_col7, #T_b0a41_row8_col9 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_b0a41_row5_col8 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_b0a41_row5_col9, #T_b0a41_row8_col2 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_b0a41_row6_col0, #T_b0a41_row8_col3 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_b0a41_row6_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_b0a41_row6_col3 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_b0a41_row6_col5 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_b0a41_row6_col7 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_b0a41_row6_col8 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_b0a41_row6_col9 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_b0a41_row7_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_b0a41_row7_col3 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_b0a41_row7_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_b0a41_row7_col6 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_b0a41_row8_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_b0a41_row8_col4 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_b0a41_row8_col5 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_b0a41_row8_col6 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_b0a41_row8_col7 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_b0a41_row9_col0 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_b0a41_row9_col1 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_b0a41_row9_col2 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_b0a41_row9_col3 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_b0a41_row9_col4 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_b0a41_row9_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_b0a41_row9_col6 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_b0a41_row9_col7 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_b0a41_row9_col8 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b0a41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0a41_level0_col0" class="col_heading level0 col0" >FLUX.1</th>
#       <th id="T_b0a41_level0_col1" class="col_heading level0 col1" >FLUX.2</th>
#       <th id="T_b0a41_level0_col2" class="col_heading level0 col2" >FLUX.3</th>
#       <th id="T_b0a41_level0_col3" class="col_heading level0 col3" >FLUX.4</th>
#       <th id="T_b0a41_level0_col4" class="col_heading level0 col4" >FLUX.5</th>
#       <th id="T_b0a41_level0_col5" class="col_heading level0 col5" >FLUX.6</th>
#       <th id="T_b0a41_level0_col6" class="col_heading level0 col6" >FLUX.7</th>
#       <th id="T_b0a41_level0_col7" class="col_heading level0 col7" >FLUX.8</th>
#       <th id="T_b0a41_level0_col8" class="col_heading level0 col8" >FLUX.9</th>
#       <th id="T_b0a41_level0_col9" class="col_heading level0 col9" >FLUX.10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0a41_level0_row0" class="row_heading level0 row0" >FLUX.1</th>
#       <td id="T_b0a41_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b0a41_row0_col1" class="data row0 col1" >0.977680</td>
#       <td id="T_b0a41_row0_col2" class="data row0 col2" >0.929653</td>
#       <td id="T_b0a41_row0_col3" class="data row0 col3" >0.924147</td>
#       <td id="T_b0a41_row0_col4" class="data row0 col4" >0.948202</td>
#       <td id="T_b0a41_row0_col5" class="data row0 col5" >0.962880</td>
#       <td id="T_b0a41_row0_col6" class="data row0 col6" >0.941278</td>
#       <td id="T_b0a41_row0_col7" class="data row0 col7" >0.914964</td>
#       <td id="T_b0a41_row0_col8" class="data row0 col8" >0.903705</td>
#       <td id="T_b0a41_row0_col9" class="data row0 col9" >0.934990</td>
#     </tr>
#     <tr>
#       <th id="T_b0a41_level0_row1" class="row_heading level0 row1" >FLUX.2</th>
#       <td id="T_b0a41_row1_col0" class="data row1 col0" >0.977680</td>
#       <td id="T_b0a41_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b0a41_row1_col2" class="data row1 col2" >0.968441</td>
#       <td id="T_b0a41_row1_col3" class="data row1 col3" >0.969030</td>
#       <td id="T_b0a41_row1_col4" class="data row1 col4" >0.983980</td>
#       <td id="T_b0a41_row1_col5" class="data row1 col5" >0.975410</td>
#       <td id="T_b0a41_row1_col6" class="data row1 col6" >0.954968</td>
#       <td id="T_b0a41_row1_col7" class="data row1 col7" >0.949872</td>
#       <td id="T_b0a41_row1_col8" cl

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Uniform 1D filter

# %%
from scipy.ndimage.filters import uniform_filter1d
train_x = pd.DataFrame(uniform_filter1d(train_x, axis=1, size=50))
test_x = pd.DataFrame(uniform_filter1d(test_x, axis=1, size=50))
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11016\567218587.py:1: DeprecationWarning: Please use `uniform_filter1d` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import uniform_filter1d

# %%
plot_train_df = train_x.loc[:4,:'200'].reset_index()
plot_train_df = plot_train_df.melt(id_vars=['index'],var_name="Flux Index", 
        value_name="Flux Intensity")
sns.set_style("dark")
g = sns.lineplot(x="Flux Index", y="Flux Intensity", hue="index",
                  data=plot_train_df,legend=False)
g.set(xticklabels=[])
plt.title('Filtered Flux Intensity for many Exoplanet Containing Star')
plt.savefig('Filtered_Flux_Intensity.png',dpi=800)

# %% [markdown]
# ### Standard normalization and scaling

# %%
from sklearn.preprocessing import StandardScaler, normalize

train_x = normalize(train_x)
test_x = normalize(test_x)

train_x = StandardScaler().fit_transform(train_x)
test_x = StandardScaler().fit_transform(test_x)

# %% [markdown]
# ### Fast Fourier Transform

# %%
four_train_x = np.real(np.fft.fft(train_x,axis=1))
four_test_x = np.real(np.fft.fft(test_x,axis=1))

plt.plot(four_train_x[0,:])
plt.title('Fourier Transform - Single Star')
plt.xlabel('Frequency')
plt.ylabel('Intensity')
plt.savefig('Fourier_Transform.png',dpi=800)

# %% [markdown]
# ### SMOTE

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
train_x_prepped, train_y_prepped = sm.fit_resample(train_x, train_y)
test_x_prepped = test_x
test_y_prepped = test_y.to_numpy()
print(sum(train_y_prepped==0), sum(train_y_prepped==1))
# Out:
# 5050 5050

# %%
four_train_x_prepped, four_train_y_prepped = sm.fit_resample(four_train_x, train_y)
four_test_x_prepped = four_test_x
four_test_y_prepped = test_y.to_numpy()
print(sum(four_train_y_prepped==0), sum(four_train_y_prepped==1))
# Out:
# 5050 5050

# %% [markdown]
# ## Data Modelling

# %% [markdown]
# ### Logistic Regression with and without Fast Fourier Transform (FFT)

# %%
from keras.models import Sequential
from keras.regularizers import L1L2
from keras.utils import to_categorical
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import SGD, Adam
from sklearn.model_selection import GridSearchCV
from keras.layers import Dense, Conv1D, Flatten,MaxPool1D,BatchNormalization,Dropout
from sklearn.metrics import confusion_matrix

# %%
train_y_prepped_oh = to_categorical(train_y_prepped)
test_y_prepped_oh = to_categorical(test_y_prepped)
four_train_y_prepped_oh = to_categorical(four_train_y_prepped)
four_test_y_prepped_oh = to_categorical(four_test_y_prepped)

# %%
model = Sequential()
model.add(Dense(2,activation='softmax',
                input_dim=train_x_prepped.shape[1]))
optimizer = SGD(lr=.01)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', 
                metrics=['accuracy'])
history = model.fit(train_x_prepped, train_y_prepped_oh,epochs=40)
# Out:
# C:\Users\HP\.conda\envs\tensorflow\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.5502 - accuracy: 0.7536
# Epoch 2/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.4108 - accuracy: 0.8245
# Epoch 3/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3508 - accuracy: 0.8524
# Epoch 4/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.3144 - accuracy: 0.8731
# Epoch 5/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2916 - accuracy: 0.8824
# Epoch 6/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2800 - accuracy: 0.8885
# Epoch 7/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2644 - accuracy: 0.8979
# Epoch 8/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2484 - accuracy: 0.9049
# Epoch 9/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2438 - accuracy: 0.9068
# Epoch 10/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2366 - accuracy: 0.9079
# Epoch 11/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2235 - accuracy: 0.9140
# Epoch 12/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2211 - accuracy: 0.9160
# Epoch 13/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2120 - accuracy: 0.9203
# Epoch 14/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2094 - accuracy: 0.9222
# Epoch 15/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2054 - accuracy: 0.9242
# Epoch 16/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.2014 - accuracy: 0.9230
# Epoch 17/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1982 - accuracy: 0.9279
# Epoch 18/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1964 - accuracy: 0.9268
# Epoch 19/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1917 - accuracy: 0.9278
# Epoch 20/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1853 - accuracy: 0.9322
# Epoch 21/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1848 - accuracy: 0.9325
# Epoch 22/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1777 - accuracy: 0.9349
# Epoch 23/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1758 - accuracy: 0.9356
# Epoch 24/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1750 - accuracy: 0.9366
# Epoch 25/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1755 - accuracy: 0.9350
# Epoch 26/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1709 - accuracy: 0.9372
# Epoch 27/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1682 - accuracy: 0.9368
# Epoch 28/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1665 - accuracy: 0.9392
# Epoch 29/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1656 - accuracy: 0.9390
# Epoch 30/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1625 - accuracy: 0.9414
# Epoch 31/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1605 - accuracy: 0.9418
# Epoch 32/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1591 - accuracy: 0.9432
# Epoch 33/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1570 - accuracy: 0.9428
# Epoch 34/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1560 - accuracy: 0.9443
# Epoch 35/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1533 - accuracy: 0.9449
# Epoch 36/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1523 - accuracy: 0.9466
# Epoch 37/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1516 - accuracy: 0.9484
# Epoch 38/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1509 - accuracy: 0.9459
# Epoch 39/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1456 - accuracy: 0.9500
# Epoch 40/40
# 316/316 [==============================] - 1s 2ms/step - loss: 0.1461 - accuracy: 0.9472

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy - LR')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Log_Reg_Accuracy.png',dpi=800)
plt.show()


plt.plot(history.history['loss'])
plt.title('Model loss - LR')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Log_Reg_Loss.png',dpi=800)
plt.show()

# %% [markdown]
# ### Confusion Matrices

# %%
y_pred = np.argmax(model.predict(test_x_prepped), axis=1)
cf_matrix = confusion_matrix(test_y_prepped, y_pred)

group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap="Purples")
plt.title('Logistic Regression Confusion Matrix')
plt.savefig('Log_Reg_Con_Mat.png',dpi=800)
# Out:
# 18/18 [==============================] - 0s 2ms/step

# %%
model = Sequential()
model.add(Dense(2,activation='softmax',
                input_dim=train_x_prepped.shape[1]))
optimizer = SGD(lr=1)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', 
                metrics=['accuracy'])
history = model.fit(four_train_x_prepped, four_train_y_prepped_oh,epochs=40)
# Out:
# Epoch 1/40
# C:\Users\HP\.conda\envs\tensorflow\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 316/316 [==============================] - 1s 2ms/step - loss: 86313.8203 - accuracy: 0.6550
# Epoch 2/40
# 316/316 [==============================] - 1s 2ms/step - loss: 79550.6406 - accuracy: 0.6729
# Epoch 3/40
# 316/316 [==============================] - 1s 2ms/step - loss: 77355.9219 - accuracy: 0.6735
# Epoch 4/40
# 316/316 [==============================] - 1s 2ms/step - loss: 78359.5781 - accuracy: 0.6748
# Epoch 5/40
# 316/316 [==============================] - 1s 2ms/step - loss: 75433.4062 - accuracy: 0.6872
# Epoch 6/40
# 316/316 [==============================] - 1s 2ms/step - loss: 76399.6094 - accuracy: 0.6834
# Epoch 7/40
# 316/316 [==============================] - 1s 2ms/step - loss: 75046.3906 - accuracy: 0.6951
# Epoch 8/40
# 316/316 [==============================] - 1s 2ms/step - loss: 73195.7266 - accuracy: 0.6875
# Epoch 9/40
# 316/316 [==============================] - 1s 2ms/step - loss: 74850.2031 - accuracy: 0.6905
# Epoch 10/40
# 316/316 [==============================] - 1s 2ms/step - loss: 72715.9062 - accuracy: 0.6940
# Epoch 11/40
# 316/316 [==============================] - 1s 2ms/step - loss: 72905.4141 - accuracy: 0.6903
# Epoch 12/40
# 316/316 [==============================] - 1s 2ms/step - loss: 71490.0781 - accuracy: 0.6999
# Epoch 13/40
# 316/316 [==============================] - 1s 2ms/step - loss: 70844.0625 - accuracy: 0.6923
# Epoch 14/40
# 316/316 [==============================] - 1s 2ms/step - loss: 71260.8281 - accuracy: 0.6970
# Epoch 15/40
# 316/316 [==============================] - 1s 2ms/step - loss: 72975.0469 - accuracy: 0.7006
# Epoch 16/40
# 316/316 [==============================] - 1s 2ms/step - loss: 70357.2109 - accuracy: 0.7016
# Epoch 17/40
# 316/316 [==============================] - 1s 2ms/step - loss: 66311.3281 - accuracy: 0.7039
# Epoch 18/40
# 316/316 [==============================] - 1s 2ms/step - loss: 70545.7188 - accuracy: 0.7002
# Epoch 19/40
# 316/316 [==============================] - 1s 2ms/step - loss: 69084.7812 - accuracy: 0.6993
# Epoch 20/40
# 316/316 [==============================] - 1s 2ms/step - loss: 71323.8281 - accuracy: 0.6996
# Epoch 21/40
# 316/316 [==============================] - 1s 2ms/step - loss: 69880.4375 - accuracy: 0.7049
# Epoch 22/40
# 316/316 [==============================] - 1s 2ms/step - loss: 70857.3203 - accuracy: 0.7024
# Epoch 23/40
# 316/316 [==============================] - 1s 2ms/step - loss: 68440.5391 - accuracy: 0.6991
# Epoch 24/40
# 316/316 [==============================] - 1s 2ms/step - loss: 73620.7344 - accuracy: 0.6935
# Epoch 25/40
# 316/316 [==============================] - 1s 2ms/step - loss: 67927.3984 - accuracy: 0.7060
# Epoch 26/40
# 316/316 [==============================] - 1s 2ms/step - loss: 72176.4453 - accuracy: 0.6979
# Epoch 27/40
# 316/316 [==============================] - 1s 2ms/step - loss: 65102.8984 - accuracy: 0.7112
# Epoch 28/40
# 316/316 [==============================] - 1s 2ms/step - loss: 72696.8047 - accuracy: 0.6994
# Epoch 29/40
# 316/316 [==============================] - 1s 2ms/step - loss: 69205.6250 - accuracy: 0.7056
# Epoch 30/40
# 316/316 [==============================] - 1s 2ms/step - loss: 64928.8320 - accuracy: 0.7099
# Epoch 31/40
# 316/316 [==============================] - 1s 2ms/step - loss: 70980.9219 - accuracy: 0.6999
# Epoch 32/40
# 316/316 [==============================] - 1s 2ms/step - loss: 66792.1641 - accuracy: 0.7015
# Epoch 33/40
# 316/316 [==============================] - 1s 2ms/step - loss: 69125.1250 - accuracy: 0.7077
# Epoch 34/40
# 316/316 [==============================] - 1s 2ms/step - loss: 65877.6562 - accuracy: 0.7079
# Epoch 35/40
# 316/316 [==============================] - 1s 2ms/step - loss: 67730.7812 - accuracy: 0.7090
# Epoch 36/40
# 316/316 [==============================] - 1s 2ms/step - loss: 65314.2695 - accuracy: 0.7107
# Epoch 37/40
# 316/316 [==============================] - 1s 2ms/step - loss: 68396.6641 - accuracy: 0.7118
# Epoch 38/40
# 316/316 [==============================] - 1s 2ms/step - loss: 70849.8516 - accuracy: 0.7053
# Epoch 39/40
# 316/316 [==============================] - 1s 2ms/step - loss: 62138.8867 - accuracy: 0.7190
# Epoch 40/40
# 316/316 [==============================] - 1s 2ms/step - loss: 64328.4219 - accuracy: 0.7159

# %%
sns.set_palette(sns.color_palette("tab10"))
plt.plot(history.history['accuracy'])
plt.title('Model accuracy - LR_FFT')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Fourier_Log_Reg_Accuracy.png',dpi=800)
plt.show()


plt.plot(history.history['loss'])
plt.title('Model loss - LR_FFT')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Fourier_Log_Reg_Loss.png',dpi=800)
plt.show()

# %%
four_y_pred = np.argmax(model.predict(four_test_x_prepped), axis=1)
cf_matrix = confusion_matrix(test_y, four_y_pred)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap="Purples")
plt.title('Logistic Regression Confusion Matrix - Fourier')
plt.savefig('Fourier_Log_Reg_Con_Mat.png',dpi=800)
# Out:
# 18/18 [==============================] - 0s 1ms/step

# %% [markdown]
# ### Feed Forward Neural Network with and without FFT

# %%
model = Sequential()
n_cols = train_x_prepped.shape[1]
model.add(Dense(200, activation='relu', input_shape=(n_cols,)))
model.add(Dense(200, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1,activation='sigmoid'))
optimizer = Adam(learning_rate=0.000001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(train_x_prepped, train_y_prepped,epochs=35)
# Out:
# Epoch 1/35
# 316/316 [==============================] - 2s 5ms/step - loss: 0.6645 - accuracy: 0.5671
# Epoch 2/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.5624 - accuracy: 0.7028
# Epoch 3/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.4925 - accuracy: 0.7900
# Epoch 4/35
# 316/316 [==============================] - 1s 5ms/step - loss: 0.4332 - accuracy: 0.8470
# Epoch 5/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.3810 - accuracy: 0.8866
# Epoch 6/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.3358 - accuracy: 0.9164
# Epoch 7/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.2973 - accuracy: 0.9382
# Epoch 8/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.2641 - accuracy: 0.9486
# Epoch 9/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.2347 - accuracy: 0.9578
# Epoch 10/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.2091 - accuracy: 0.9660
# Epoch 11/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.1870 - accuracy: 0.9718
# Epoch 12/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.1677 - accuracy: 0.9762
# Epoch 13/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.1509 - accuracy: 0.9803
# Epoch 14/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.1362 - accuracy: 0.9825
# Epoch 15/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.1233 - accuracy: 0.9857
# Epoch 16/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.1120 - accuracy: 0.9869
# Epoch 17/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.1020 - accuracy: 0.9886
# Epoch 18/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0931 - accuracy: 0.9899
# Epoch 19/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0852 - accuracy: 0.9905
# Epoch 20/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0781 - accuracy: 0.9917
# Epoch 21/35
# 316/316 [==============================] - 1s 5ms/step - loss: 0.0717 - accuracy: 0.9925
# Epoch 22/35
# 316/316 [==============================] - 1s 5ms/step - loss: 0.0660 - accuracy: 0.9932
# Epoch 23/35
# 316/316 [==============================] - 1s 5ms/step - loss: 0.0608 - accuracy: 0.9936
# Epoch 24/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0562 - accuracy: 0.9940
# Epoch 25/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0521 - accuracy: 0.9943
# Epoch 26/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0483 - accuracy: 0.9948
# Epoch 27/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0449 - accuracy: 0.9952
# Epoch 28/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0417 - accuracy: 0.9957
# Epoch 29/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0389 - accuracy: 0.9959
# Epoch 30/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0364 - accuracy: 0.9963
# Epoch 31/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0340 - accuracy: 0.9967
# Epoch 32/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0319 - accuracy: 0.9969
# Epoch 33/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0299 - accuracy: 0.9973
# Epoch 34/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0281 - accuracy: 0.9973
# Epoch 35/35
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0264 - accuracy: 0.9975

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy - Feed Forward')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('FF_Net_Accuracy.png',dpi=800)
plt.show()

plt.plot(history.history['loss'])
plt.title('Model loss - Feed Forward')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('FF_Net_Loss.png',dpi=800)
plt.show()

# %% [markdown]
# ### Confusion Matrices

# %%
cf_matrix = confusion_matrix(test_y, y_pred)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap="Purples")
plt.title('Feed-Forward Network Confusion Matrix')
plt.savefig('FF_Net_Con_Mat.png',dpi=800)

# %%
model = Sequential()
n_cols = train_x_prepped.shape[1]
model.add(Dense(200, activation='relu', input_shape=(n_cols,)))
model.add(Dense(200, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1,activation='sigmoid'))
optimizer = Adam(learning_rate=0.000001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(four_train_x_prepped, four_train_y_prepped,epochs=30)
# Out:
# Epoch 1/30
# 316/316 [==============================] - 2s 4ms/step - loss: 5.4690 - accuracy: 0.5269
# Epoch 2/30
# 316/316 [==============================] - 1s 4ms/step - loss: 3.9802 - accuracy: 0.5824
# Epoch 3/30
# 316/316 [==============================] - 1s 5ms/step - loss: 3.0331 - accuracy: 0.6269
# Epoch 4/30
# 316/316 [==============================] - 1s 5ms/step - loss: 2.4146 - accuracy: 0.6791
# Epoch 5/30
# 316/316 [==============================] - 1s 5ms/step - loss: 1.9865 - accuracy: 0.7164
# Epoch 6/30
# 316/316 [==============================] - 1s 5ms/step - loss: 1.6592 - accuracy: 0.7541
# Epoch 7/30
# 316/316 [==============================] - 1s 5ms/step - loss: 1.4062 - accuracy: 0.7863
# Epoch 8/30
# 316/316 [==============================] - 1s 4ms/step - loss: 1.2059 - accuracy: 0.8110
# Epoch 9/30
# 316/316 [==============================] - 1s 5ms/step - loss: 1.0438 - accuracy: 0.8324
# Epoch 10/30
# 316/316 [==============================] - 1s 5ms/step - loss: 0.9100 - accuracy: 0.8535
# Epoch 11/30
# 316/316 [==============================] - 1s 4ms/step - loss: 0.7994 - accuracy: 0.8701
# Epoch 12/30
# 316/316 [==============================] - 1s 5ms/step - loss: 0.7101 - accuracy: 0.8840
# Epoch 13/30
# 316/316 [==============================] - 1s 5ms/step - loss: 0.6353 - accuracy: 0.8972
# Epoch 14/30
# 316/316 [==============================] - 1s 5ms/step - loss: 0.5703 - accuracy: 0.9075
# Epoch 15/30
# 316/316 [==============================] - 2s 5ms/step - loss: 0.5130 - accuracy: 0.9157
# Epoch 16/30
# 316/316 [==============================] - 1s 4ms/step - loss: 0.4624 - accuracy: 0.9232
# Epoch 17/30
# 316/316 [==============================] - 1s 4ms/step - loss: 0.4167 - accuracy: 0.9291
# Epoch 18/30
# 316/316 [==============================] - 1s 4ms/step - loss: 0.3755 - accuracy: 0.9361
# Epoch 19/30
# 316/316 [==============================] - 1s 4ms/step - loss: 0.3386 - accuracy: 0.9434
# Epoch 20/30
# 316/316 [==============================] - 1s 4ms/step - loss: 0.3061 - accuracy: 0.9491
# Epoch 21/30
# 316/316 [==============================] - 1s 5ms/step - loss: 0.2770 - accuracy: 0.9543
# Epoch 22/30
# 316/316 [==============================] - 1s 4ms/step - loss: 0.2505 - accuracy: 0.9586
# Epoch 23/30
# 316/316 [==============================] - 1s 5ms/step - loss: 0.2261 - accuracy: 0.9616
# Epoch 24/30
# 316/316 [==============================] - 1s 4ms/step - loss: 0.2034 - accuracy: 0.9640
# Epoch 25/30
# 316/316 [==============================] - 1s 4ms/step - loss: 0.1820 - accuracy: 0.9669
# Epoch 26/30
# 316/316 [==============================] - 1s 4ms/step - loss: 0.1623 - accuracy: 0.9692
# Epoch 27/30
# 316/316 [==============================] - 1s 4ms/step - loss: 0.1439 - accuracy: 0.9714
# Epoch 28/30
# 316/316 [==============================] - 1s 4ms/step - loss: 0.1272 - accuracy: 0.9738
# Epoch 29/30
# 316/316 [==============================] - 1s 4ms/step - loss: 0.1120 - accuracy: 0.9769
# Epoch 30/30
# 316/316 [==============================] - 1s 4ms/step - loss: 0.0981 - accuracy: 0.9796

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy - Feed Forward_FFT')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Log_Reg_Accuracy.png',dpi=800)
plt.show()


plt.plot(history.history['loss'])
plt.title('Model loss - Feed Forward_FFT')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('Log_Reg_Loss.png',dpi=800)
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score
y_pred = model.predict(four_test_x_prepped)
fpr, tpr, thresholds = roc_curve(test_y, y_pred)
crossover_index = np.min(np.where(1.-fpr <= tpr))
crossover_cutoff = thresholds[crossover_index]

y_pred[y_pred < crossover_cutoff] = 0
y_pred[y_pred >= crossover_cutoff] = 1

cf_matrix = confusion_matrix(test_y, y_pred)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap="Purples")
plt.title('Feed-Forward Fourier Network Confusion Matrix')
plt.savefig('Four_FF_Net_Con_Mat.png',dpi=800)
# Out:
# 18/18 [==============================] - 0s 2ms/step

# %% [markdown]
# ### CNN with and without FFT

# %%
model = Sequential()
n_cols = train_x_prepped.shape[1]
model.add(Conv1D(filters=512, kernel_size=16, activation='relu', input_shape=(n_cols,1)))
model.add(MaxPool1D(strides=4))
model.add(Conv1D(filters=256, kernel_size=16, activation='relu'))
model.add(MaxPool1D(strides=4))
model.add(Conv1D(filters=128, kernel_size=16, activation='relu'))
model.add(MaxPool1D(strides=4))
model.add(Conv1D(filters=64, kernel_size=16, activation='relu'))
model.add(MaxPool1D(strides=4))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
optimizer = Adam(learning_rate=0.00001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
train_x_prepped_rs = np.expand_dims(train_x_prepped, axis=2)
test_x_prepped_rs = np.expand_dims(test_x_prepped, axis=2)
class_weight = {0: 1.,
                1: 137.}
history = model.fit(train_x_prepped_rs, train_y_prepped,epochs=18,class_weight=class_weight)
# Out:
# Epoch 1/18
# 316/316 [==============================] - 952s 3s/step - loss: 10.5836 - accuracy: 0.4998
# Epoch 2/18
# 316/316 [==============================] - 955s 3s/step - loss: 2.2966 - accuracy: 0.5437
# Epoch 3/18
# 316/316 [==============================] - 933s 3s/step - loss: 1.2976 - accuracy: 0.7255
# Epoch 4/18
# 316/316 [==============================] - 952s 3s/step - loss: 0.8285 - accuracy: 0.8270
# Epoch 5/18
# 316/316 [==============================] - 959s 3s/step - loss: 0.5208 - accuracy: 0.8908
# Epoch 6/18
# 316/316 [==============================] - 967s 3s/step - loss: 0.3301 - accuracy: 0.9323
# Epoch 7/18
# 316/316 [==============================] - 990s 3s/step - loss: 0.2148 - accuracy: 0.9537
# Epoch 8/18
# 316/316 [==============================] - 937s 3s/step - loss: 0.1392 - accuracy: 0.9708
# Epoch 9/18
# 316/316 [==============================] - 935s 3s/step - loss: 0.0992 - accuracy: 0.9797
# Epoch 10/18
# 316/316 [==============================] - 944s 3s/step - loss: 0.0738 - accuracy: 0.9850
# Epoch 11/18
# 316/316 [==============================] - 935s 3s/step - loss: 0.0560 - accuracy: 0.9884
# Epoch 12/18
# 316/316 [==============================] - 935s 3s/step - loss: 0.0433 - accuracy: 0.9912
# Epoch 13/18
# 316/316 [==============================] - 930s 3s/step - loss: 0.0368 - accuracy: 0.9924
# Epoch 14/18
# 316/316 [==============================] - 932s 3s/step - loss: 0.0258 - accuracy: 0.9950
# Epoch 15/18
# 316/316 [==============================] - 938s 3s/step - loss: 0.0203 - accuracy: 0.9956
# Epoch 16/18
# 316/316 [==============================] - 939s 3s/step - loss: 0.0165 - accuracy: 0.9964
# Epoch 17/18
# 316/316 [==============================] - 933s 3s/step - loss: 0.0127 - accuracy: 0.9973
# Epoch 18/18
# 316/316 [==============================] - 947s 3s/step - loss: 0.0103 - accuracy: 0.9979

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy - CNN')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()


plt.plot(history.history['loss'])
plt.title('Model loss - CNN')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ### Confusion Matrices

# %%
y_pred = model.predict(test_x_prepped_rs)

fpr, tpr, thresholds = roc_curve(test_y, y_pred)
crossover_index = np.min(np.where(1.-fpr <= tpr))
crossover_cutoff = thresholds[crossover_index]

y_pred[y_pred < crossover_cutoff] = 0
y_pred[y_pred >= crossover_cutoff] = 1
cf_matrix = confusion_matrix(four_test_y_prepped, y_pred)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap="Purples")
plt.title('Convolutional Neural Network Confusion Matrix')
# Out:
# 18/18 [==============================] - 17s 962ms/step
# Text(0.5, 1.0, 'Convolutional Neural Network Confusion Matrix')

# %%
model = Sequential()
n_cols = train_x_prepped.shape[1]
model.add(Conv1D(filters=512, kernel_size=16, activation='relu', input_shape=(n_cols,1)))
model.add(MaxPool1D(strides=4))
model.add(Conv1D(filters=256, kernel_size=16, activation='relu'))
model.add(MaxPool1D(strides=4))
model.add(Conv1D(filters=128, kernel_size=16, activation='relu'))
model.add(MaxPool1D(strides=4))
model.add(Conv1D(filters=64, kernel_size=16, activation='relu'))
model.add(MaxPool1D(strides=4))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
optimizer = Adam(learning_rate=0.00001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
four_train_x_prepped_rs = np.expand_dims(four_train_x_prepped, axis=2)
four_test_x_prepped_rs = np.expand_dims(four_test_x_prepped, axis=2)
class_weight = {0: 1.,
                1: 137.}
history = model.fit(four_train_x_prepped_rs, train_y_prepped,epochs=12,class_weight=class_weight)
# Out:
# Epoch 1/12
# 316/316 [==============================] - 946s 3s/step - loss: 11.0604 - accuracy: 0.5005
# Epoch 2/12
# 316/316 [==============================] - 936s 3s/step - loss: 2.8891 - accuracy: 0.5572
# Epoch 3/12
# 316/316 [==============================] - 979s 3s/step - loss: 1.1955 - accuracy: 0.7654
# Epoch 4/12
# 316/316 [==============================] - 988s 3s/step - loss: 0.4972 - accuracy: 0.8936
# Epoch 5/12
# 316/316 [==============================] - 983s 3s/step - loss: 0.2592 - accuracy: 0.9473
# Epoch 6/12
# 316/316 [==============================] - 977s 3s/step - loss: 0.1590 - accuracy: 0.9697
# Epoch 7/12
# 316/316 [==============================] - 995s 3s/step - loss: 0.1072 - accuracy: 0.9787
# Epoch 8/12
# 316/316 [==============================] - 974s 3s/step - loss: 0.0748 - accuracy: 0.9850
# Epoch 9/12
# 316/316 [==============================] - 995s 3s/step - loss: 0.0531 - accuracy: 0.9898
# Epoch 10/12
# 316/316 [==============================] - 981s 3s/step - loss: 0.0393 - accuracy: 0.9924
# Epoch 11/12
# 316/316 [==============================] - 977s 3s/step - loss: 0.0279 - accuracy: 0.9947
# Epoch 12/12
# 316/316 [==============================] - 973s 3s/step - loss: 0.0212 - accuracy: 0.9958

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy - CNN_FFT')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()


plt.plot(history.history['loss'])
plt.title('Model loss - CNN_FFT')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
four_test_x_prepped_rs = np.expand_dims(four_test_x_prepped, axis=2)
y_pred = model.predict(four_test_x_prepped_rs)

fpr, tpr, thresholds = roc_curve(test_y, y_pred)
crossover_index = np.min(np.where(1.-fpr <= tpr))
crossover_cutoff = thresholds[crossover_index]

y_pred[y_pred < crossover_cutoff] = 0
y_pred[y_pred >= crossover_cutoff] = 1
cf_matrix = confusion_matrix(four_test_y_prepped, y_pred)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap="Purples")
plt.title('Fourier Convolutional Neural Network Confusion Matrix')
# Out:
# 18/18 [==============================] - 17s 961ms/step
# Text(0.5, 1.0, 'Fourier Convolutional Neural Network Confusion Matrix')
